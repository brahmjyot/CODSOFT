# %% [markdown]
# <a href="https://colab.research.google.com/github/brahmjyot/CODSOFT/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **IRIS FLOWER CLASSIFICATION**

# %%
import pandas as pd

# %% [markdown]
# Loading dataset

# %%
df = pd.read_csv('/content/IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# checking for null values

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
X = df.drop(['species'],axis= 'columns')
y = df['species']

# %% [markdown]
# Hyperparameter tuning and best model selection using GridSearchCV

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm' : {
        'model' : SVC(gamma='auto'),
        'params' : {
            'C' : [1,10,20],
            'kernel' : ['rbf','linear']
    }
     },
    'Random_forest' : {
        'model' : RandomForestClassifier(),
        'params' : {
            'n_estimators' : [1,5,10, 20, 40]
        }
    },
    'Naive_bayes' : {
        'model' : GaussianNB(),
        'params' : {
            'var_smoothing' : [1.2,5.5,6.7]
        }
    },
    'Naive_bayes' : {
        'model' :MultinomialNB(),
        'params' : {
            'alpha' : [1.0 , 2.0, 3.0, 10.0 , 20.0]
        }
    },
    'Decision_tree' : {
        'model' :DecisionTreeClassifier(),
        'params' : {
            'criterion' : ['gini', 'entropy', 'log_loss']
        }
    },
    'K nearest neighbor' : {
        'model' : KNeighborsClassifier(),
        'params' : {
            'n_neighbors' : [5, 10,15]
        }
    },

}

# %%
scores =[]

for model_name , mp in model_params.items():
    clf = GridSearchCV(mp['model'],mp['params'], cv= 5, return_train_score = False)
    clf.fit(X,y)
    scores.append({
        'model' : model_name,
        'best_score' : clf.best_score_,
        'best_params' : clf.best_params_
    })

df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                 model  best_score                best_params
# 0                 svm    0.980000  {'C': 1, 'kernel': 'rbf'}
# 1       Random_forest    0.966667       {'n_estimators': 20}
# 2         Naive_bayes    0.966667            {'alpha': 10.0}
# 3       Decision_tree    0.960000      {'criterion': 'gini'}
# 4  K nearest neighbor    0.980000        {'n_neighbors': 10}

# %% [markdown]
# ## SVM as well as K-nearest neighbor fits best for this classification
